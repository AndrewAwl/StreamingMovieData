# %% [markdown]
# # Andy Awlasewicz - Final Project
# # Understanding Movie Streaming Data

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
streamdata = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')

# %%
imdbmovies = pd.read_csv('IMDB movies.csv', parse_dates = ['date_published'])

# %%
mychecks = pd.read_csv('checked.csv')

# %%
top250 = pd.read_csv('imdbs+top+250.csv')

# %%
imdbratings = pd.read_csv('IMDB ratings.csv')

# %%
streamdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# dtypes: float64(2), int64(8), object(7)
# memory usage: 2.2+ MB

# %%
streamdata.shape
# Out:
# (16744, 16)

# %%
streamdata.head(10)
# Out:
#    Unnamed: 0  ID                              Title  Year  Age  IMDb  \
# 0           0   1                          Inception  2010  13+   8.8
# 1           1   2                         The Matrix  1999  18+   8.7
# 2           2   3             Avengers: Infinity War  2018  13+   8.5
# 3           3   4                 Back to the Future  1985   7+   8.5
# 4           4   5     The Good, the Bad and the Ugly  1966  18+   8.8
# 5           5   6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 6           6   7                        The Pianist  2002  18+   8.5
# 7           7   8                   Django Unchained  2012  18+   8.4
# 8           8   9            Raiders of the Lost Ark  1981   7+   8.4
# 9           9  10               Inglourious Basterds  2009  18+   8.3
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
# 5             97%        1     0            0        0     0
# 6             95%        1     0            1        0     0
# 7             87%        1     0            0        0     0
# 8             95%        1     0            0        0     0
# 9             89%        1     0            0        0     0
#
#                                      Directors  \
# 0                            Christopher Nolan
# 1               Lana Wachowski,Lilly Wachowski
# 2                      Anthony Russo,Joe Russo
# 3                              Robert Zemeckis
# 4                                 Sergio Leone
# 5  Bob Persichetti,Peter Ramsey,Rodney Rothman
# 6                               Roman Polanski
# 7                            Quentin Tarantino
# 8                             Steven Spielberg
# 9                            Quentin Tarantino
#
#                                      Genres  \
# 0          Action,Adventure,Sci-Fi,Thriller
# 1                             Action,Sci-Fi
# 2                   Action,Adventure,Sci-Fi
# 3                   Adventure,Comedy,Sci-Fi
# 4                                   Western
# 5  Animation,Action,Adventure,Family,Sci-Fi
# 6                 Biography,Drama,Music,War
# 7                             Drama,Western
# 8                          Action,Adventure
# 9                       Adventure,Drama,War
#
#                                 Country  \
# 0          United States,United Kingdom
# 1                         United States
# 2                         United States
# 3                         United States
# 4              Italy,Spain,West Germany
# 5                         United States
# 6  United Kingdom,France,Poland,Germany
# 7                         United States
# 8                         United States
# 9                 Germany,United States
#
#                                       Language  Runtime
# 0                      English,Japanese,French    148.0
# 1                                      English    136.0
# 2                                      English    149.0
# 3                                      English    116.0
# 4                                      Italian    161.0
# 5                              English,Spanish    117.0
# 6                       English,German,Russian    150.0
# 7                English,German,French,Italian    165.0
# 8  English,German,Hebrew,Spanish,Arabic,Nepali    115.0
# 9                English,German,French,Italian    153.0

# %%
streamdata.drop(columns=['Unnamed: 0'], inplace=True)

# %%
streamdata['Type'].value_counts()
# Out:
# 0    16744
# Name: Type, dtype: int64

# %%
streamdata.drop(columns=['Type'], inplace=True)

# %%
# Had originally just used a concatenate column but saw a good example of how to use apply that was similar so applied it here
# https://queirozf.com/entries/pandas-dataframes-apply-examples

def concat (title, year, director):
    return str(title) + '-' + str(year) + '-' + str(director)
streamdata['UniqueID'] = streamdataa['Title','Year','Directors'].apply(lambda row: concatenate(row['Title'], row['Year'], row['Directors']), axis=1)


# streamdata['UniqueID'] = streamdata['Title'] + '-' + streamdata['Year'].astype(str) + '-' + streamdata['Directors']

# %%
streamdata.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    Netflix  Hulu  Prime Video  Disney+                       Directors  \
# 0        1     0            0        0               Christopher Nolan
# 1        1     0            0        0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0         Anthony Russo,Joe Russo
# 3        1     0            0        0                 Robert Zemeckis
# 4        1     0            1        0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language  Runtime  \
# 0  English,Japanese,French    148.0
# 1                  English    136.0
# 2                  English    149.0
# 3                  English    116.0
# 4                  Italian    161.0
#
#                                             UniqueID
# 0                   Inception-2010-Christopher Nolan
# 1     The Matrix-1999-Lana Wachowski,Lilly Wachowski
# 2  Avengers: Infinity War-2018-Anthony Russo,Joe ...
# 3            Back to the Future-1985-Robert Zemeckis
# 4   The Good, the Bad and the Ugly-1966-Sergio Leone

# %%
imdbmovies.shape
# Out:
# (85855, 22)

# %%
imdbmovies.head(10)
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000009                                         Miss Jerry
# 1     tt0000574                        The Story of the Kelly Gang
# 2     tt0001892                                     Den sorte drøm
# 3     tt0002101                                          Cleopatra
# 4     tt0002130                                          L'Inferno
# 5     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 6     tt0002423                                     Madame DuBarry
# 7     tt0002445                                         Quo Vadis?
# 8     tt0002452                              Independenta Romaniei
# 9     tt0002461                                        Richard III
#
#                                       original_title  year date_published  \
# 0                                         Miss Jerry  1894     1894-10-09
# 1                        The Story of the Kelly Gang  1906     1906-12-26
# 2                                     Den sorte drøm  1911     1911-08-19
# 3                                          Cleopatra  1912     1912-11-13
# 4                                          L'Inferno  1911     1911-03-06
# 5  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# 6                                     Madame DuBarry  1919     1919-11-26
# 7                                         Quo Vadis?  1913     1913-03-01
# 8                              Independenta Romaniei  1912     1912-09-01
# 9                                        Richard III  1912     1912-10-15
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
# 5           Biography, Drama        60               USA  English
# 6  Biography, Drama, Romance        85           Germany   German
# 7             Drama, History       120             Italy  Italian
# 8               History, War       120           Romania      NaN
# 9                      Drama        55       France, USA  English
#
#                                 director  ...  \
# 0                        Alexander Black  ...
# 1                           Charles Tait  ...
# 2                              Urban Gad  ...
# 3                     Charles L. Gaskill  ...
# 4    Francesco Bertolini, Adolfo Padovan  ...
# 5                          Sidney Olcott  ...
# 6                         Ernst Lubitsch  ...
# 7                        Enrico Guazzoni  ...
# 8  Aristide Demetriade, Grigore Brezeanu  ...
# 9           André Calmettes, James Keane  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 5  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
# 6  Pola Negri, Emil Jannings, Harry Liedtke, Edua...
# 7  Amleto Novelli, Gustavo Serena, Carlo Cattaneo...
# 8  Aristide Demetriade, Constanta Demetriade, Con...
# 9  Robert Gemp, Frederick Warde, Albert Gardner, ...
#
#                                          description avg_vote votes  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154
# 1  True story of notorious Australian outlaw Ned ...      6.1   589
# 2  Two men of high rank are both wooing the beaut...      5.8   188
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# 5  An account of the life of Jesus Christ, based ...      5.7   484
# 6  The story of Madame DuBarry, the mistress of L...      6.8   753
# 7  An epic Italian film "Quo Vadis" influenced ma...      6.2   273
# 8  The movie depicts the Romanian War of Independ...      6.7   198
# 9  Richard of Gloucester uses manipulation and mu...      5.5   225
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 0         NaN               NaN                   NaN       NaN
# 1      $ 2250               NaN                   NaN       NaN
# 2         NaN               NaN                   NaN       NaN
# 3     $ 45000               NaN                   NaN       NaN
# 4         NaN               NaN                   NaN       NaN
# 5         NaN               NaN                   NaN       NaN
# 6         NaN               NaN                   NaN       NaN
# 7   ITL 45000               NaN                   NaN       NaN
# 8  ROL 400000               NaN                   NaN       NaN
# 9     $ 30000               NaN                   NaN       NaN
#
#   reviews_from_users  reviews_from_critics
# 0                1.0                   2.0
# 1                7.0                   7.0
# 2                5.0                   2.0
# 3               25.0                   3.0
# 4               31.0                  14.0
# 5               13.0                   5.0
# 6               12.0                   9.0
# 7                7.0                   5.0
# 8                4.0                   1.0
# 9                8.0                   1.0
#
# [10 rows x 22 columns]

# %%
imdbmovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 23710 non-null  object
#  17  usa_gross_income       15326 non-null  object
#  18  worlwide_gross_income  31016 non-null  object
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 14.4+ MB

# %%
imdbmovies['UniqueID'] = imdbmovies['title'] + '-' + imdbmovies['year'].astype(str) + '-' + imdbmovies['director']

# %%
# https://www.geeksforgeeks.org/how-to-do-a-vlookup-in-python-using-pandas/
mergedata = pd.merge(left=streamdata, right=imdbmovies,  on='UniqueID', how='left')

# %%
mergedata.shape
#something is wrong because there is only supposed to be max 16.7k rows here... 
# duplicates in my imdbmovie dataset creating multiple hits?
# Out:
# (79180, 38)

# %%
mergedata.columns
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Netflix',
#        'Hulu', 'Prime Video', 'Disney+', 'Directors', 'Genres', 'Country',
#        'Language', 'Runtime', 'UniqueID', 'imdb_title_id', 'title',
#        'original_title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
imdbmovies['UniqueID'].value_counts()
# Out:
# The Lost Jungle-1934-David Howard, Armand Schaefer       2
# Anno Domini 681-1981-Ludmil Staikov                      2
# Don Chisciotte-1933-Georg Wilhelm Pabst                  2
# I violenti di Rio Bravo-1965-Robert Siodmak              2
# Shadow of Chinatown-1936-Robert F. Hill                  2
#                                                         ..
# Ni luo he nu er-1987-Hsiao-Hsien Hou                     1
# Zero Focus-1961-Yoshitarô Nomura                         1
# Sadie-2018-Megan Griffiths                               1
# Kim Bok-nam salinsageonui jeonmal-2010-Cheol-soo Jang    1
# Topaz-1969-Alfred Hitchcock                              1
# Name: UniqueID, Length: 85763, dtype: int64

# %%
imdbmovies[imdbmovies['UniqueID'] == 'The Lost Jungle-1934-David Howard, Armand Schaefer']
# Out:
#      imdb_title_id            title   original_title  year date_published  \
# 1877     tt0025420  The Lost Jungle  The Lost Jungle  1934     1934-03-22
# 1878     tt0025421  The Lost Jungle  The Lost Jungle  1934     1934-06-13
#
#                          genre  duration country language  \
# 1877  Action, Adventure, Drama       243     USA  English
# 1878                 Adventure        68     USA  English
#
#                            director  ...  \
# 1877  David Howard, Armand Schaefer  ...
# 1878  David Howard, Armand Schaefer  ...
#
#                                             description avg_vote votes budget  \
# 1877  Animal trainer Clyde Beatty heads a rescue par...      4.8   195    NaN
# 1878  Feature version of the 1934 Mascot serial "The...      4.1   161    NaN
#
#       usa_gross_income  worlwide_gross_income metascore reviews_from_users  \
# 1877               NaN                    NaN       NaN               10.0
# 1878               NaN                    NaN       NaN               11.0
#
#      reviews_from_critics                                           UniqueID
# 1877                  8.0  The Lost Jungle-1934-David Howard, Armand Scha...
# 1878                  2.0  The Lost Jungle-1934-David Howard, Armand Scha...
#
# [2 rows x 23 columns]

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html
imdbmovies[imdbmovies.duplicated(subset=['UniqueID'])]
# Out:
#       imdb_title_id                                            title  \
# 1878      tt0025421                                  The Lost Jungle
# 11148     tt0056173                              La leggenda di Lobo
# 12405     tt0059682                          I violenti di Rio Bravo
# 16288     tt0070754                                         Superman
# 23970     tt0095342                                      I Love N.Y.
# ...             ...                                              ...
# 83109     tt7731512                              Code Blue the Movie
# 83537     tt7980094  The Oscar Nominated Short Films 2018: Animation
# 83963     tt8236566                                      The Dip Run
# 85083     tt9062580                                            Alone
# 85724     tt9760934                                          Villain
#
#                                         original_title  year date_published  \
# 1878                                   The Lost Jungle  1934     1934-06-13
# 11148                               The Legend of Lobo  1962     1962-11-07
# 12405                           Der Schatz der Azteken  1965     1967-03-30
# 16288                                         Superman  1973     1973-09-09
# 23970                                      I Love N.Y.  1987     1987-05-04
# ...                                                ...   ...            ...
# 83109                              Code Blue the Movie  2018     2018-07-27
# 83537  The Oscar Nominated Short Films 2018: Animation  2018     2018-02-09
# 83963                                      The Dip Run  2018     2018-11-20
# 85083                                            Alone  2019     2019-05-20
# 85724                                          Villain  2018     2018-10-12
#
#                            genre  duration                      country  \
# 1878                   Adventure        68                          USA
# 11148          Adventure, Family        67                          USA
# 12405         Adventure, Western       101  West Germany, Italy, France
# 16288  Action, Adventure, Sci-Fi       104                          USA
# 23970              Comedy, Drama       100                          USA
# ...                          ...       ...                          ...
# 83109                      Drama       127                        Japan
# 83537                  Animation        83                          USA
# 83963                     Comedy        96                          USA
# 85083   Adventure, Drama, Sci-Fi        69                          USA
# 85724                     Action       132                        India
#
#                                 language                       director  ...  \
# 1878                             English  David Howard, Armand Schaefer  ...
# 11148                            English                            NaN  ...
# 12405                             German                 Robert Siodmak  ...
# 16288                            English                            NaN  ...
# 23970                            English                            NaN  ...
# ...                                  ...                            ...  ...
# 83109                           Japanese                            NaN  ...
# 83537                            English                            NaN  ...
# 83963                            English                            NaN  ...
# 85083  English, Spanish, French, Italian                            NaN  ...
# 85724                            Bengali                            NaN  ...
#
#                                              description avg_vote votes  \
# 1878   Feature version of the 1934 Mascot serial "The...      4.1   161
# 11148  Tells the life story of a wolf named Lobo. He ...      7.0   441
# 12405  Dr. Karl Sternau, the personal physician of th...      5.4   470
# 16288  A compilation of four episodes of "The Adventu...      6.5   181
# 23970  Photographer Mario Cotone is hired to cover a ...      4.1   109
# ...                                                  ...      ...   ...
# 83109  The 'helicopter doctor' team is back with perf...      5.9   389
# 83537  An exclusive feature-length presentation showc...      7.5   161
# 83963  4 friends travel half way across the United St...      2.6   169
# 85083                                                NaN      6.4   206
# 85724  "Villain"narrates the story of Raja, the prota...      5.0   117
#
#            budget  usa_gross_income  worlwide_gross_income metascore  \
# 1878          NaN               NaN                    NaN       NaN
# 11148         NaN               NaN                    NaN       NaN
# 12405         NaN               NaN                    NaN       NaN
# 16288         NaN               NaN                    NaN       NaN
# 23970         NaN               NaN                    NaN       NaN
# ...           ...               ...                    ...       ...
# 83109         NaN               NaN             $ 78778562       NaN
# 83537         NaN               NaN                    NaN       NaN
# 83963    $ 150000               NaN                    NaN       NaN
# 85083  EUR 570000               NaN                    NaN       NaN
# 85724         NaN               NaN                    NaN       NaN
#
#       reviews_from_users reviews_from_critics  \
# 1878                11.0                  2.0
# 11148                7.0                  NaN
# 12405                2.0                  4.0
# 16288                4.0                  NaN
# 23970                5.0                  NaN
# ...                  ...                  ...
# 83109                2.0                  1.0
# 83537                1.0                  7.0
# 83963               15.0                  1.0
# 85083                NaN                  NaN
# 85724                NaN                  NaN
#
#                                                 UniqueID
# 1878   The Lost Jungle-1934-David Howard, Armand Scha...
# 11148                                                NaN
# 12405        I violenti di Rio Bravo-1965-Robert Siodmak
# 16288                                                NaN
# 23970                                                NaN
# ...                                                  ...
# 83109                                                NaN
# 83537                                                NaN
# 83963                                                NaN
# 85083                                                NaN
# 85724                                                NaN
#
# [91 rows x 23 columns]

# %%
len(imdbmovies[imdbmovies.UniqueID.isnull()])
# Out:
# 87

# %%
len(streamdata[streamdata.UniqueID.isnull()])
# Out:
# 726

# %%
# Using Title - Year - Director as a unique identifier to join to IMDB may not be the most feasible

# %%
streamdata.columns
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Netflix',
#        'Hulu', 'Prime Video', 'Disney+', 'Directors', 'Genres', 'Country',
#        'Language', 'Runtime', 'UniqueID'],
#       dtype='object')

# %%
netflixmask = streamdata['Netflix'] == 1
disneymask = streamdata['Disney+'] == 1
hulumask = streamdata['Hulu'] == 1
primemask = streamdata['Prime Video'] == 1

# %%
streamdata[netflixmask]['IMDb'].mean()
# Out:
# 6.252963393375944

# %%
streamdata[disneymask]['IMDb'].mean()
# Out:
# 6.441385435168739

# %%
streamdata[hulumask]['IMDb'].mean()
# Out:
# 6.1381165919282505

# %%
streamdata[primemask]['IMDb'].mean()
# Out:
# 5.770910312395029

# %%
services = ['Netflix', 'Hulu', 'Prime Video', 'Disney+']

# %%
barmeans = [streamdata[netflixmask]['IMDb'].mean(), streamdata[hulumask]['IMDb'].mean(), streamdata[primemask]['IMDb'].mean(), streamdata[disneymask]['IMDb'].mean() ]

# %%
barmeans
# Out:
# [6.252963393375944, 6.1381165919282505, 5.770910312395029, 6.441385435168739]

# %%
plt.bar(services, barmeans)
plt.xlabel('Service')
plt.ylabel('IMDB Rating Avg')
plt.title('Average IMDB Rating for each Service')
plt.ylim(5,6.5)
# Out:
# (5.0, 6.5)

# %%
#streamdata.groupby(['year'])['movie_id'].count().plot(kind='bar')
